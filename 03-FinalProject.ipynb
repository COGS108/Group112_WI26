# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# In this project, our team analyzed National Park Service data to determine how season and region influenced how long people spend at national parks in the United States. We analyzed monthly recreation visitor hours and recreation visits from 2004 - 2024, and used it to look at seasonal and regional trends. We found that visitors tend to spend the fewest hours per visit, and visit less during the winter months, an effect that is present across all regions, but exacerbated in the Pacific Northwest parks, where visitors seem to flock in the summer. We also found that parks are not equally distributed in their average length of visitation, and their number of visits. Some parks recieve the vast majority of total visits. There are sme parks that tend to have more shorter visits, and others that favor longer, but fewer visits. While we found a lot of interesting data trends, the diverse nature of the parks and the nature of some park's popularity and unique weather conditions causing hazards may limit our findings.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Seraphina Jarboe - Writing – original draft(Hypothesis, Authors, Project Timeline, Dataset 1), Writing – review & editing (all sections)
# - Denise Wu Mendez - Writing – original draft(Data sections, logging team expectations from group discussion, data overview)
# - Kate Sun - Writing – original draft (Ethics and final research question phrasing)
# - Shawn Chou - Writing – original draft (Background and prior work section), Data curation
# - Chak Sing Chan - Writing – original draft (Background and prior work section)

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do seasonal (Winter : Dec-Feb, Spring : Mar-May, Summer : Jun-Aug, Fall : Sep-Nov) differences influence recreation visitation and average recreation hours per visit (Recreation hours/Recreation visits) between U.S. National Parks in the Northeast, Midwest, Intermountains, and Pacific West regions from 2000 to 2024?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# As a team, the famous U.S National Parks grabbed our attention during the process of selecting a topic. We believed that there were many interesting datasets and analysis that could be made regarding this topic. The U.S National Parks are spread among different states. However, they are different in many aspects. For instance, some national parks are more populated and easily accessible, while some are in less populated areas and are harder to get to. Each region's national park has its own unique features. Generally speaking, National Parks that are located near the major cities will be more accessible than the ones that are located in the more remote areas, which the latter will require greater effort and planning to visit.
#
# In addition to the regional difference, National Parks also have seasonal differences. Each national park has its own peak and off-season based on what tourists plan to do there. These factors greatly influence tourists in deciding whether they choose to visit which national park and the duration of their stay there. Hence, this project aims to explore how regional and seasonal differences in the US National Parks from 2000 to 2024 affect recreational visitation and hours spent per visit.
#
# A report by the National Park Service (NPS) shows that the reported number of recreational visits is 331.9 million in the year 2024, with visitors spending approximately 1.4 billion hours in national parks.<a name="ref1"></a>[1](#footnote1) Additionally, visitors distributed their visits throughout the year, where more than half of the parks show peak periods in February to June, and October to December. This shows that the peak season is during spring and fall which is the opposite to popular belief that the peak season is summertime. Instead, tourists visit throughout the year in different periods, and over half of the park shows that spring and fall had an above-average number of visits.
#
# The National Park Service also found out that climate change not only affects resources of national parks, but they discovered that it influenced visitation patterns. Their data shows that 95% of parks has great relationship between air temperature and visitation.<a name="ref2"></a>[2](#footnote2) Visitation declines as the monthly average temperature is over 80F. This shows that a lot of the park visitors avoid hot weather, which leads to this phenomenon.
#
# A report from the NPS in 2021 shows that the most visited national park is the Great Smoky Mountain National Park with 14 million recreation visits, with Zion National Park in second with 5 million recreation visits.<a name="ref3"></a>[3](#footnote3) The main reason why the Great Smoky Mountain National Park is so popular is due to its geographical location. It is located within a day's drive for most US population including cities like Chicago, Atlanta, Nashville, etc. Which made it very easy and accessible for a wide range of the population to visit without having to drive too far.<a name="ref4"></a>[4](#footnote4)
#
#
# <a name="footnote1"></a>1. [^](#ref1) National Park Service. “VUStats Dashboard - Social Science (U.S. National Park Service).” *Www.nps.gov*, 17 Oct. 2024, www.nps.gov/subjects/socialscience/visitor-use-statistics-dashboard.htm.
#
# <a name="footnote2"></a>
# 2. [^](#ref2) Fisichelli, Nicholas A., et al. “Protected Area Tourism in a Changing Climate: Will Visitation at US National Parks Warm up or Overheat?” *PLOS ONE*, vol. 10, no. 6, 17 June 2015, p. e0128226, https://doi.org/10.1371/journal.pone.0128226.
#
# <a name="footnote3"></a>
# 3. [^](#ref3) “Visitation Highlights - Social Science (U.S. National Park Service).” *Nps.gov*, 2018, www.nps.gov/subjects/socialscience/highlights.htm.
#
# <a name="footnote4"></a>
# 4. [^](#ref4) Gatlinburg, Mailing Address: 107 Park Headquarters Road, and TN 37738 Phone:436-1200 Contact Us. “Visitor Experience & Stewardship - Great Smoky Mountains National Park (U.S. National Park Service).” *Www.nps.gov*, www.nps.gov/grsm/learn/management/ves.htm.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that the winter season (defined as December through Feb) will have lower recreation hours and recreation visits (as collected by the NPS) across all parks, due to colder weather and shorter daylight hours. We also predict that this effect will be stronger in the Midwest region (which includes SD, OH, MO, AR, IN, MI, ND, and MN) and Northeast region (which includes ME, WV, and VA) due to average higher latitudes and snow. Using data about total recreation hours and total recreation visits, we also believe that the average time of recreation visits may be lower during winter months, which could be related to hours of daylight. Therefore we predict that there will be a strong correlation between season of the year, and recreation hours, as well as season of the year and recreation visits.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
# - Dataset #1
#   - Dataset Name: National Park Service Visitor Use Statistics (IRMA)
#   - Link to the dataset: https://irma.nps.gov/Stats/SSRSReports/National%20Reports/Query%20Builder%20for%20Public%20Use%20Statistics%20(1979%20-%20Last%20Calendar%20Year)
#   - Number of observations:
#     Monthy observations, for each park unit, for this project we will take data from (2000 - 2024)
#   - Number of variables:
#      - National Parks
#      - Year
#      - Month
#      - Recreation visits
#      - Non-recreation visits
#      - Recreation visitor hours
#      - Non-recreation visitor hours
#      - Overnight stays (by type)
#   - Recreation visits: are defined as the number of people entering a park for recreational purposes in a given month. This will be used as the primary measure of park visitation
#   - Visitor hours: used to construct a new variable. Average time spent per visit = recreation vistior hours/recreation visits. This will provides a proxy for visit length since the dataset does not directly report average duration
#   - Year & Month: is to analyze trends over time, create season variables
#      - Winter: Dec-Feb
#      - Spring: Mar-May
#      - Summer: Jun-Aug
#      - Fall: Sep-Nov
#   - Park Name used as a unique identifier to merge with external datasets (region, park type, weather)
#   - Overnight stays: can be used additional measure of park use and to distinguish between day use and overnight visitation patterns
#   - Non-recreation visits: will not be used in the main visitation measure because they include commuting and administrative use rather than tourism-related visits
#   - One shortcoming is that visitations does not mean unique visitations, the dataset only takes into account number of recreation visits not individual people. We cannot measure number of unique visitors and repeat visitation behavior.
#   - There is no direction "average length of stay" because we only have recreation visitation hours and recreation visits so we must construct average stay = visitor hours/visits. This assumes that all visitor hours come from recreation visitors and reporting is accurate accross parks
#   - There is no visor characteristics, can not analyze differences by age, income, residency (local vs tourists), group size, transportation mode. So the analysis is limited to park patterns not people.
#   - There is no weather in the dataset, you cannot directly measure temperature, rain, snow and extreme events, so you cannot test weather effects unless you merge another dataset
#   - Potential differences in counting methods across parks. They may use different tools like traffic counters, fee recipts, or manual estimates which can create inconsistency in visitation estimates especially for older data
#   - Some missing or suppressed data: for certain praks or early years: some months may be missing, some overnight categories may be blank.
#   - Measures park-level use, not specific activites: Based on the dataset we won't be able to tell from hiking vs camping vs sightseeing, or which areas inside the park are crowded

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1BanvjJ7btH6WlQlTZslI0XRIRQ8MDD8I', 'filename':'2000-2024 National Park Data.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress: 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# Successfully downloaded: 2000-2024 National Park Data.csv

# %% [markdown]
# ### National Park Service Visitor Use Statistics Dataset
#
# This data came from the Query Builder for Public Use Statistics provided by the National Parks Service. There are a few complications that must be considered when using this dataset. One is that  this dataset is that 2025 data is still preliminary, however this is not a problem for us since our cutoff for date is 2024. Additionally, some parks were established after 2004, so we must be conscious in our analyses that not all parks have data for every year. Not all parks report statistics, as they may be newer and lack the resources to collect such data. Some parks also shut down for COVID-19 and thus visitor data may be affected by this, which must be considered. The National Parks Service has had a formalized method of record keeping since the 1980s, which aims to collect statistics across parks in a way that allows for statistical analysis, and upkeeps quality. Therefore, there are no glaring issues regarding our dataset for this planned use.
#
# Regions for our dataset include parks in the following states (Using state abbreviations):
# - Northeast: ME, WV, VA
# - Intermountain: UT, TX, CO, NM, MT, AZ, WY
# - Midwest: SD, OH, MO, AR, IN, MI, ND, MN
# - Pacific west: CA, OR, NV, HI, WA, AS
#
# Additionally, we have defined seasons as:
# - Winter: Dec-Feb
# - Spring: Mar-May
# - Summer: Jun-Aug
# - Fall: Sep-Nov
#
# The metrics of the table are provided below as defined by the NPS on their "Visitor Use Statistics Definitions Page" <a name="ref5"></a>[5](#footnote5):
#
# A visitor hour is defined by the NPS as "The presence of one or more persons, excluding NPS personnel, in a park for continuous, intermittent, or simultaneous periods of time aggregating one hour (e.g., one person for one hour, two persons for one-half hour, etc. Although same day attendance at detached parts of the same park are considered duplicate counts and not reported as separate visits, the time involved at detached units is added together for the visitor hour estimate." and becomes a recreation visitor hour when "associated with a recreation visit." All of the data we will be using will be related to recreation visits (as opposed to non-recreation visits that include brief pass throughs of park land, workers doing their jobs, and research activities).
#
# A recreation visit is defined by the NPS as "The entry of a person onto lands or waters administered by the NPS except for non-reportable and non-recreation visits. Funeral parties at National Cemeteries, school groups, etc. are reportable as ‘recreation visits’ since their use aligns with the purpose for which the park was established. Visits originating on surface vehicles (trains, boats, other) and aircraft may be counted if they stop and disembark passengers on NPS administrated territory. The applicable rule is that one entrance per individual per day may be counted."
#
#
# <a name="footnote5"></a>5. [^](#ref5) National Park Service. “NPS Visitor Use Statistics Definitions” *Www.nps.gov*, 21 Feb. 2024, https://www.nps.gov/subjects/socialscience/nps-visitor-use-statistics-definitions.htm

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## importing pandas for the data
import pandas as pd

## loading in the dataset
national_parks = pd.read_csv('data/00-raw/2000-2024 National Park Data.csv')

## Grabbing and renaming the columns that we are going to be analyzing
national_parks_cleaned = national_parks[['ParkName', 'Region', 'State', 'Year', 'Month', 'RecreationVisits', 'RecreationHours']]
national_parks_cleaned = national_parks_cleaned.rename(columns={
    "ParkName": "Park Name",
    "RecreationVisits": "Recreation Visits",
    "RecreationHours": "Recreation Hours"
})

## Changing the Visists # and Hours # into floats for calculation purpose for the Hours Per Visit Column
national_parks_cleaned["Recreation Visits"] = pd.to_numeric(
    national_parks_cleaned["Recreation Visits"].astype(str).str.replace(",", "")
)

national_parks_cleaned["Recreation Hours"] = pd.to_numeric(
    national_parks_cleaned["Recreation Hours"].astype(str).str.replace(",", ""),
)

## Adding the Hours Per Visit Column
national_parks_cleaned['Hours Per Visit'] = (national_parks_cleaned['Recreation Hours'] / national_parks_cleaned['Recreation Visits']).round(2)

## Size of Dataset
national_parks_cleaned.shape ## (14351, 8)
# Out:
# (14351, 8)

# %%
## Developing a IQR range to flag outliers (For the Recreation visits)
Q1 = national_parks_cleaned['Recreation Visits'].quantile(0.25)
Q3 = national_parks_cleaned['Recreation Visits'].quantile(0.75)

## Calculating the IQR
IQR = Q3 - Q1

## Constructing an upperbound
upper_bound = Q3 + 1.5 * IQR

## Flag outliers
visits_outliers = national_parks_cleaned[national_parks_cleaned['Recreation Visits'] > upper_bound]
## Showing the highest outliers
visits_outliers.sort_values('Recreation Visits', ascending = False)
# Out:
#                        Park Name          Region State  Year  Month  \
# 3905             Gateway Arch NP        Midwest     MO  2000      7
# 3917             Gateway Arch NP        Midwest     MO  2001      7
# 13709             Yellowstone NP  Intermountain     WY  2021      7
# 3929             Gateway Arch NP        Midwest     MO  2002      7
# 3965             Gateway Arch NP        Midwest     MO  2005      7
# ...                          ...             ...   ...   ...    ...
# 129                    Acadia NP      Northeast     ME  2010     10
# 9509   New River Gorge NP & PRES      Northeast     WV  2021      7
# 3365          Cuyahoga Valley NP        Midwest     OH  2005      7
# 7716              Joshua Tree NP   Pacific West     CA  2018      2
# 4255                  Glacier NP  Intermountain     MT  2004      9
#
#        Recreation Visits  Recreation Hours  Hours Per Visit
# 3905             1162217           4648868             4.00
# ...

# %% [markdown]
# There are 1403 rows that are above the upper bound of the visits IQR, though this isn’t caused by errors. They are statistical outliers, because we can see that parks like Acadia and Zion are really popular and gain a lot of visitors. These observations reflect real-world park usage rather than data errors. Therefore, we will be keeping these values for the analysis.

# %%
## Constructing IQR for flagging outliers (For Hours Per Visits)
q1 = national_parks_cleaned['Hours Per Visit'].quantile(0.25)
q3 = national_parks_cleaned['Hours Per Visit'].quantile(0.75)
iqr = q3 - q1

## Calculating the upper bound
hpv_upper = q3 + 1.5 * iqr

## Finding the outliers
hpv_outliers = national_parks_cleaned[national_parks_cleaned['Hours Per Visit'] > hpv_upper]
## Showing the highest outliers
hpv_outliers.sort_values('Hours Per Visit', ascending = False)
# Out:
#                 Park Name          Region State  Year  Month  \
# 3142       Crater Lake NP   Pacific West     OR  2011     12
# 3153       Crater Lake NP   Pacific West     OR  2012     11
# 3154       Crater Lake NP   Pacific West     OR  2012     12
# 7280       Isle Royale NP        Midwest     MI  2006     10
# 9827    North Cascades NP   Pacific West     WA  2023      1
# ...                   ...             ...   ...   ...    ...
# 13763         Yosemite NP   Pacific West     CA  2001      1
# 2954   Channel Islands NP   Pacific West     CA  2021      4
# 13762         Yosemite NP   Pacific West     CA  2000     12
# 4550      Grand Canyon NP  Intermountain     AZ  2004      4
# 8118   Lassen Volcanic NP   Pacific West     CA  2001      8
#
#        Recreation Visits  Recreation Hours  Hours Per Visit
# 3142                   0              1600              inf
# 3153                   0               360              inf
# ...

# %% [markdown]
# There are 1932 outliers according to the upper bound calculation using the IQR. We suspect that with this variable there might be more suspicious outliers. By looking at the highest few Hours Per Visit outliers we can observe some extreme numeric data. These cases are actually not data errors but reflect multiple day stays (small visitor count with long stays), or remote national parks (really far away) that require a longer stay. Since they are valid data we decided that it is appropriate to keep them in the analysis.

# %%
## Loading the Cleaned Data into the processed folder
processed_path = "data/02-processed/nps_visitation_2000_2024_processed.csv"
national_parks_cleaned.to_csv(processed_path, index = False)

# %%
## Loading the new and cleaned dataset
np = pd.read_csv("data/02-processed/nps_visitation_2000_2024_processed.csv")
## Fully Cleaned Dataset size
np.shape #(14264, 8)

np
# Out:
#        Park Name          Region State  Year  Month  Recreation Visits  \
# 0      Acadia NP      Northeast     ME  2000      1              22500
# 1      Acadia NP      Northeast     ME  2000      2              23848
# 2      Acadia NP      Northeast     ME  2000      3              35423
# 3      Acadia NP      Northeast     ME  2000      4              78555
# 4      Acadia NP      Northeast     ME  2000      5             166456
# ...          ...             ...   ...   ...    ...                ...
# 14346    Zion NP  Intermountain     UT  2024      8             470995
# 14347    Zion NP  Intermountain     UT  2024      9             506117
# 14348    Zion NP  Intermountain     UT  2024     10             517501
# 14349    Zion NP  Intermountain     UT  2024     11             311297
# 14350    Zion NP  Intermountain     UT  2024     12             235404
#
#        Recreation Hours  Hours Per Visit
# 0                148500             6.60
# ...

# %%
## Summaryt statistics for each of the variables
national_parks_cleaned[['Recreation Visits', 'Recreation Hours', 'Hours Per Visit']].describe().round(2)
# Out:
#        Recreation Visits  Recreation Hours  Hours Per Visit
# count           14351.00          14351.00         14267.00
# mean           108126.02         938915.63              inf
# std            149219.60        2050229.34              NaN
# min                 0.00              0.00             0.15
# 25%             18061.00          68792.50             2.90
# 50%             54262.00         241482.00             4.66
# 75%            126065.50         758535.00             7.44
# max           1162217.00       20212391.00              inf

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %%
## Loading the fully wrangled data
nps = pd.read_csv("data/02-processed/nps_visitation_2000_2024_processed.csv")
nps

## import seaborn and matplotlib for plotting
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Distribution of Recreation Visits
#
# We are going to first start off with a histogram that shows the distibution of the Recreation Visits. A histogram is the most simple and straight forward way to visualize distribution. Including this is essential as it immediately reveals how uneven park popularity is across the system. It also highlights that while the vast majority of national parks have relatively low, consistent visitation, a few locations act as outliers that attract huge crowds.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
sns.histplot(nps['Recreation Visits'], bins = 100)
plt.title('Distribution of Recreation Visits')
plt.show()

# %% [markdown]
# As can be seen from the histogram, the distribution of recreation visits is significantly skewed to the right. Furthermore, the histogram shows that most parks don't have many visitors in most months, and some really popular park getting high visitations. We can see the high visitation from the long right tail. This histogram suggests that the visitation distribution is uneven throughout the national parks that we are analysing.

# %% [markdown]
# #### Relationship between Recreation Hours and Recreation Visits
#
# Now, we are going to generate a scatterplot that helps us visualize the relationship between recreation visits and hours. We believe that providing this comparison is valuable since it shows that park usage isn't solely determined by headcounts, but also the duration of those visits. Visualizing this relationship will also allow us to gain a more comprehensive understanding of visitor behavior patterns across different locations.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
sns.scatterplot(
    data = nps,
    x = 'Recreation Visits',
    y = 'Recreation Hours',
    alpha = 0.4
)
plt.title('Relationship between Recreation Hours and Visits')
plt.show()

# %% [markdown]
# This scatterplot shows the strong relationship between the recreation hours and visits. As we can observe when the visits go up the hours generally goes up as well. This is expected as more visitor equals more hours accumlated. Though if we look at the spread we can observe something interesting. We can see that there are many positive slope lines, indicating that diffferent parks keeps the vistors inside the park for different durations. Some can keep them for very long, some are just quick visits. This scatterplot shows that the Recreation hours and visits has a strong relationships, though different parks differs the trend.

# %% [markdown]
# #### Region Difference in Park Visitation
#
# Next, we decided to include a boxplot that displays the distribution of recreation visits broken down by region. We chose to use a boxplot as it allows for clear, visual comparisons of the spread, averages, and outliers of data across multiple categories at once. With including this, we can better identify geographic trends and understand whether tourist traffic is evenly spread out or highly concentrated in some specific region.

# %%
sns.boxplot(
    data = nps,
    x = 'Region',
    y = 'Recreation Visits'
)

plt.title('Recreation Visits by Region')
plt.show()

# %% [markdown]
# This boxplot shows the distribution of tourist numbers across four regions: Northeast, Intermountain, Midwest, and Pacific West. The distribution of recreation visits varies significantly from place to place, as can be seen from the graph, the Northeast has higher receation visits than the other three places, while the Intermountain and Pacific West have lower numbers. In summary, this graph shows that recreation visits is not evenly distributed across different places.

# %% [markdown]
# #### Season Trends in Park Visitation
#
# Furthermore, we decided to provide data on seasonal trends in park visitation since it reveals how park popularity shifts from month to month. We believe a line plot is best for this visualization because it can clearly track continuous trends and changes over a set period of time. By tracking these changes in the busy and quiet periods, we can better understand exactly where parks face the highest demand for things like staffing, supplies, or maintenance.

# %%
monthly_visits = (
    nps.groupby('Month')['Recreation Visits']
    .mean()
    .reset_index()
)

sns.lineplot(
    data = monthly_visits,
    x = 'Month',
    y = 'Recreation Visits',
    marker = 'o'
)
plt.title('Average Recreation Visits by Month')
plt.xlabel('Month')
plt.ylabel('Average Recreation Visits')
plt.show()

# %% [markdown]
# This line plot demonstrates a clear bell-shaped trend in average recreation visits throughout the year. We can see that visits start to climb in the spring and reach its peak in July (Month 7), with an average of over 225000 visitors. This is likely due to warmer weathers and summer vacations. After July, the numbers drop steadily through fall until they hit a low point in winter, staying around 50000 visits during December (Month 12) and January (Month 1). The steep rise and fall in the graph indicates that while the park is popular, most of that activity is packed into only a few months. This suggests how the need for park resources, supplies and staffing will be most critical during summers.

# %% [markdown]
# #### Visitor Behavior Across National Parks
#
# For this next part, we are creating a barplot to analyze visitor behavior, specifically the average hours spent per visit, as it provides insight on how different parks are actually utilized by the public. We chose to create a barplot since it's the most straightforward way to rank and visually compare the different categories side by side. By examining this, we can distinguish between quick, single-visit parks and longer, multi-day-visit parks, ultimately offering a complete overview of visitor behavior across national parks.

# %%
park_hpv = (
    nps.groupby('Park Name')['Hours Per Visit']
    .mean()
    .reset_index()
)

top_parks = park_hpv.sort_values(
    'Hours Per Visit',
    ascending = False
).head(15)

sns.barplot(
    data = top_parks,
    x = 'Hours Per Visit',
    y = 'Park Name'
)
plt.title('Parks with Highest Average Hours Per Visit')
plt.xlabel('Average Hours Per Visit')
plt.ylabel('Park')
plt.show()

# %% [markdown]
# This barplot shows the top 15 national parks ranked based on the average duration of visitor stays. Righ away, Isle Royale National Park stands out with the highest average duration of approximately 35 hours. This great lead is consistent with its geographic location, as it is a remote island where most people go for multi-day camping trips rather than quick single-day visits. Below that, parks like Sequoia, Kings Canyon, and Big Bend National Parks also encourages long stays, keeping visitors around for about 23-26 hours. As we move further down the graph to more famous destinations like Yellowstone, Yosemite, and the Grand Canyon, the average visit drops to roughly 15-18 hours, which seems likely to be full-day trips or single overnight stays.

# %% [markdown]
# #### Behavioral Quadrant: Recreation Visits and Stay Duration
#
# Now, we are incorporating a comparison of recreation visits and how long visitors stay. We believe using a scatterplot is most appropriate because it's especially effective in discovering correlations and identifying groupings between two different numerical variables — recreation visits and hours per visit. By mapping out these two factors, we can group parks into distinct categories, which gives us a much more complete picture of how the public interacts with the national park system.

# %%
park_summary = (
    nps.groupby('Park Name')[['Recreation Visits', 'Hours Per Visit']]
    .mean()
    .reset_index()
)

sns.scatterplot(
    data = park_summary,
    x = 'Recreation Visits',
    y = 'Hours Per Visit',
    alpha = 0.7
)
plt.axvline(park_summary['Recreation Visits'].median(), linestyle = 'dotted')
plt.axhline(park_summary['Hours Per Visit'].median(), linestyle = 'dotted')

plt.title('Park Behavioral Quadrant: Popularity VS Stay Duration')
plt.xlabel('Average Recreation Visits')
plt.ylabel('Average Hours Per Visit')
plt.show()

# %% [markdown]
# This scatterplot uses dotted lines to divide the national parks into four quadrants based on their overall popularity and average stay duration. Looking at the top-left section, we can spot a few parks with low visitor numbers but long hours of visiting (including the almost 35 hour outlier we mentioned earlier). On the other hand, the bottom-right section reflects highly popular parks that draw massive crowds of over 100000 visitors, but mostly for quick trips lasting under 5 hours. Interestingly, a large cluster of dots lie in the bottom-left quadrant, suggesting that many parks experience both low visitor numbers and shorter stay times.

# %% [markdown]
# #### Seasonal Visits by Region
#
# To better understand how the seasonal patterns affect the park visitation across the United States. We want to visualize the average number of recreation visits by season and region. We want to use a barplot for this visualization because it allows us to compare the visitation level across the catagories that we want at the same time.

# %%
season_map = {
    12:'Winter', 1:'Winter', 2:'Winter',
    3:'Spring', 4:'Spring', 5:'Spring',
    6:'Summer', 7:'Summer', 8:'Summer',
    9:'Fall', 10:'Fall', 11:'Fall'
}

nps['Season'] = nps['Month'].map(season_map)

season_region_visits = (
    nps.groupby(['Season', 'Region'])['Recreation Visits']
    .mean()
    .reset_index()
)

sns.barplot(
    data = season_region_visits,
    x = 'Season',
    y = 'Recreation Visits',
    hue = 'Region'
)
plt.title('Average Recreation Visits by Season and Region')
plt.show()

# %% [markdown]
# This graph clearly shows the seasonal differences in recreation visitation across the four national park regions. Across all the regions, summer is the season that peaks in visitation. The intermountain region and the Northeasts has the highest average visitation counts. We can clearly see for all the regions when the season hits the summer the visitation increases by at most of double. Winter in the other hand is the lowest season for the visitation, we can see that the visitation drops by not a lot more than halve.

# %% [markdown]
# ### Seasonal Hours Per Visit by Region
#
# In addition to measuing the visitation levels, we should also see how long does the visitors stay at the national park. We want to see the difference across each region and season. WE are going to use a barplot just like the last graph since it allows us to see the different catagories easily.

# %%
season_region_hours = (
    nps.groupby(['Season', 'Region'])['Hours Per Visit']
    .mean()
    .reset_index()
)

sns.barplot(
    data = season_region_hours,
    x = 'Season',
    y = 'Hours Per Visit',
    hue = 'Region'
)
plt.title('Average Hours per Visit by Season and Region')
plt.show()

# %% [markdown]
# The graph shows the average hours per visit varies across both seasons and regions. Overall, visitors tend to spend the most hours per visit in the park during the summer months. Which correlates to the recreation visits graphs. The pacific west shows the highest average hours per visit throughout all the regions with the highest during the summer. This shows that national parks such as Yosemite and Olympic, where the visitors usually tend to stay the longest. The northeast doesn't show too much change and the intermountain shows similar data. The midwest greatly increases during the summer times and has signs of decrease throughout the other seasons.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > This project will use publicly available National Park Service (NPS) data, which is aggregated at the park level. A potential source of bias is that visitation counts may be influenced by factors like park accessibility, errors in recording, or park size. We will be careful not to interpret differences in visitation as reflecting individual visitor preferences.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > A potential downstream risk is that results could be misinterpreted as reflecting individual preferences or behaviors. To mitigate this, we will frame our findings as park-level trends and avoid making claims about individual decision-making or protected groups.
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Our analysis focuses on visitation counts and camping participation and doesn't include qualitative visitor experiences, environmental impacts, or local community perspectives.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Our chosen dataset may reflect bias toward more popular or accessible parks as they tend to have more data collection systems. Smaller parks may have less accurate visitation estimates or records, which could affect regional comparisons.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We will use descriptive metrics such as visitation counts and recreation hours to examine park-level trends. We will also consider using derived measures such as average recreation hours per visit to provide context. These metrics are intended to describe patterns rather than evaluate performance or rank parks.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We would specify that the metrics and variables that we are analyzing in our data isn't a metric that is used to measure park popularity or visitation satisfaction, and this results should not be interpreted as evidence of how environmental conditions affects recreational behaviors.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > Since this project will most likely become public after we are completed, we will monitor the results by looking through comments of people that looked through our project and feedback from other collaborators. We would be paying most of our attention on feedbacks that indicated we have misinterpreted certain findings and make changes to ensure that our analysis is accurate
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > If we have users harmed by the results of our analysis we would quickly look into it as this matters a lot to us. We would correct our explanations, clairfy some limitation that we faced in our project, and revise our entire project and the parts that showed harm to users to ensure no harm is done.
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > If serious issues does happen, we would make the project private and revise everything that is necessary to ensure our project is accurate and non-harmful then we would make it public again.
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > A potential unintended use of this project is treating our analysis (visitation counts or recreation hours) as indicators of vistor satisfaction, or environment quality. To prevent this kind of unintended use we would specify in our project that all of our analysis is descriptive and focuses on trends that connects to our variable, rather than saying which park is better or not or trying to take this as an evidence as how enviromental variables connects to recreational behaviors.

# %% [markdown]
# ## Discusison and Conclusion
# Across all analyses, a consistent picture emerged: national park visitation is highly uneven, strongly seasonal, and shaped by both geography and visitor behavior. The histogram showed that most parks receive relatively low visitation while a small number attract extremely large crowds, confirming the background expectation that popularity is heavily concentrated. The scatterplot between visits and recreation hours extended this idea by showing that while more visitors generally mean more hours spent, parks differ widely in how long people stay, revealing meaningful behavioral differences beyond simple headcounts.
#
# Regional and seasonal patterns added further structure to these findings. The boxplot demonstrated that visitation varies significantly across regions, with some areas consistently drawing more tourists than others. Meanwhile, the monthly line plot confirmed a clear seasonal cycle, with visitation peaking sharply in summer and dropping in winter. These results reinforce the idea that environmental factors, accessibility, and climate shape when and where people choose to visit.
#
# The behavioral analyses deepened this understanding. Ranking parks by average hours per visit highlighted that some parks function as quick sightseeing destinations, while others—often more remote or wilderness‑oriented—encourage longer stays. The quadrant scatterplot brought these patterns together by grouping parks into categories based on both popularity and stay duration, showing that parks serve different roles within the broader system.
#
# While the overall trends were clear, some results were more complex. A few parks with low visitation but unusually long stays stood out as outliers, likely due to unique access constraints or multi‑day backcountry use. Regional averages also masked substantial park‑level variation. These inconsistencies don’t contradict the broader findings but remind us that park‑specific context matters and that simple averages can hide important nuances.
#
# This study does have limitations. The dataset is cross‑sectional rather than multi‑year, so we cannot assess long‑term trends or changes over time. Some regions or parks may also be over‑ or under‑represented depending on reporting quality. Additional variables such as demographics, weather, or park capacity could further explain the patterns we observed. More data, especially longitudinal data, would strengthen confidence in the conclusions and allow for forecasting or deeper causal analysis.
